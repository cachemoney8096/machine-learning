# %%
import torch
print(torch.__version__)
# Out:
# 2.7.1

# %%
from ultralytics import YOLO
model = YOLO('/Users/rubenhayrapetyan/Downloads/Code/FRC/machine-learning/2025-Coral_Detection_Training/robot_detection/runs/train/coral-detection-model-v14/weights/best_robot.pt')

ts_path = '/Users/rubenhayrapetyan/Downloads/Code/FRC/machine-learning/2025-Coral_Detection_Training/robot_detection/runs/train/coral-detection-model-v14/weights/best_robot.pt'
model.model.eval() 
traced_model = torch.jit.trace(model.model, torch.randn(1, 3, 640, 640))
traced_model.save(ts_path)
print(f"TorchScript model saved to {ts_path}")
# Out:
# WARNING ⚠️ The file '/Users/rubenhayrapetyan/Downloads/Code/FRC/machine-learning/2025-Coral_Detection_Training/robot_detection/runs/train/coral-detection-model-v14/weights/best_robot.pt' appears to be improperly saved or formatted. For optimal results, use model.save('filename.pt') to correctly save YOLO models.
# /Users/rubenhayrapetyan/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1488: UserWarning: 'torch.load' received a zip file that looks like a TorchScript archive dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to silence this warning)
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 from ultralytics import YOLO
# ...

# %%
# %pip install torch-tflite

# %%
import torch_tflite

tflite_path = "/Users/rubenhayrapetyan/Downloads/Code/FRC/machine-learning/2025-Coral_Detection_Training/robot_detection/runs/train/coral-detection-model-v14/weights/best_robot.tflite"

torch_tflite.export(
    ts_path,
    tflite_path,
    input_shapes=[(1, 3, 640, 640)],
    opset_version=13,  # Torch-TFLite opset
)
print(f"TFLite model saved to {tflite_path}")
