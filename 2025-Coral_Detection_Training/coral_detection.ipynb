# %%
import subprocess
import sys
import os

libraries = ["ultralytics"]

for lib in libraries:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", lib])

# %%
CLUSTER = True
if not CLUSTER:
    HOME = "/Users/rubenhayrapetyan/Downloads/Code/FRC/machine-learning/2025-Coral_Detection_Training"
else:
    HOME = "/home/rhayrapetyan/2025-Coral_Detection_Training"
    os.makedirs(f"{HOME}/coral_detection/runs/train", exist_ok=True)

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')  # load a pretrained model (recommended for training)
if CLUSTER:
    os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
    results = model.train(
        data=f"{HOME}/2025 REEFSCAPE.v2i.yolov12/data.yaml",
        epochs=100,
        imgsz=640,
        batch=16,
        name="coral-detection-model-v1",
        device=[0,1],
        workers=8,
        project=f"{HOME}/coral_detection/runs/train"
    )    
else:
    results = model.train(
        data=f"{HOME}/2025 REEFSCAPE.v2i.yolov12/data.yaml",
        epochs=100,
        imgsz=640,
        batch=16,
        name="coral-detection-model-v1",
        workers=2,
        project=f"{HOME}/coral_detection/runs/train"
    )

metrics = model.val(split="test")

# %%
from IPython.display import Image, display
import os
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/results.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/train_batch0.jpg', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/train_batch0.jpg', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/val_batch0_pred.jpg', width=600))

# %%
from IPython.display import Image, display
import os
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v1/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v12/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v13/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v14/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v15/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v16/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v17/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v123/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v124/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v125/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v126/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v127/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v128/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v129/confusion_matrix.png', width=600))
display(Image(filename=f'{HOME}/coral_detection/runs/train/coral-detection-model-v130/confusion_matrix.png', width=600))
